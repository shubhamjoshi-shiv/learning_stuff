# %%
import sys
sys.setrecursionlimit(1500)

# %%
d={(1,2):3}

# %%
d[(1,3)]=5
d[(1,3)]

# %%
known_factorial={1:1}

# known_factorial[4]
n=2
if n in known_factorial:
    print(known_factorial[n])
    
    
usetime=0

# %%
def factorial1(number):
    if number == 1:
        return 1
    else:
        return number*factorial1(number-1)

# %%
def factorial(number):
    if number == 1:
        return 1
    elif number in known_factorial:
        global usetime
        usetime+=1
        print("f",number)
        return known_factorial[number]
    else:
        sub_factorial=factorial(number-1)
        global known_factorial
        known_factorial[number-1]=sub_factorial
        ans = number*sub_factorial
        return ans

#         ans = number*factorial(number-1)
#         return ans

#         return number*factorial(number-1)
# Out:
#   File "<ipython-input-25-576dc2569bc3>", line 11
#     global known_factorial
#     ^
# SyntaxError: name 'known_factorial' is used prior to global declaration

# %%
num=555
factorial(num)
# Out:
# f 554
# ...

# %%
usetime
# factorial1(555)
# Out:
# 1

# %%
known_factorial
# Out:
# {1: 1,
#  2: 2,
#  3: 6,
#  4: 24,
#  5: 120,
#  6: 720,
#  7: 5040,
#  8: 40320,
#  9: 362880,
#  10: 3628800,
#  11: 39916800,
#  12: 479001600,
#  13: 6227020800,
#  14: 87178291200,
#  15: 1307674368000,
#  16: 20922789888000,
#  17: 355687428096000,
#  18: 6402373705728000,
#  19: 121645100408832000,
#  20: 2432902008176640000,
#  21: 51090942171709440000,
#  22: 1124000727777607680000,
#  23: 25852016738884976640000,
#  24: 620448401733239439360000,
#  25: 15511210043330985984000000,
#  26: 403291461126605635584000000,
#  27: 10888869450418352160768000000,
#  28: 304888344611713860501504000000,
#  29: 8841761993739701954543616000000,
#  30: 265252859812191058636308480000000,
#  31: 8222838654177922817725562880000000,
#  32: 263130836933693530167218012160000000,
#  33: 8683317618811886495518194401280000000,
#  34: 295232799039604140847618609643520000000,
#  35: 10333147966386144929666651337523200000000,
#  36: 371993326789901217467999448150835200000000,
# ...

# %%
i=3
print(factorial(i))
x=0
for i in range(1,2965):
    x=i
    print("###############################",i)
    print(factorial1(i))

# %%
print(1)
# 2965
# Out:
# 1
